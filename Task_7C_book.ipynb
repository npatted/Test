# %% [markdown]
# # Working With Images
# Open Image with Image Information.

# %%
import easygui
from PIL import Image
flower=Image.open('image_file.jpg')
print(flower.size)
print(flower.filename)
print(flower.format_description)
flower
# Out:
# (512, 288)
# image_file.jpg
# JPEG (ISO 10918)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x1AD93D3B8B0>

# %% [markdown]
# # Crop Image.

# %%
cut_flower= flower.crop((120,100,200,200))
cut_flower
# Out:
# <PIL.Image.Image image mode=RGB size=80x100 at 0x1AD940155E0>

# %% [markdown]
# # Copying And Pasting Images.

# %%
flower.paste(im=cut_flower,box=(300,0))
flower
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x1AD93D3B8B0>
